# %%
from diffusion_test import Test_single_parameter, Test_set_parameter

# %%
# !pip install gdown
# Out:
# ...
#   Using cached gdown-5.2.1-py3-none-any.whl.metadata (5.8 kB)
# ...
# Using cached gdown-5.2.1-py3-none-any.whl (18 kB)
# ...
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import gdown

# test data
gdown.download_folder("https://drive.google.com/drive/folders/100F2DVY4ricJ7JIuIgoCQsmtJOZ8Y7u9?usp=sharing", quiet=False)

# model
gdown.download_folder("https://drive.google.com/drive/folders/16qXsY6qx4VUIZiRx24z5QSknQpyJUs3w?usp=drive_link", quiet=False)
# Out:
# Retrieving folder contents
# Retrieving folder 1S9osdofoJCVWWjcVkmhlPitCPbPxaxUe image
# Processing file 18jDfJTkL8ecVHdUkJUAVcsYSMncKowoY 0001.pgm
# Processing file 1aeiomaFcVaCLompLW8sHHS8rTV-cFJAV 0002.pgm
# Processing file 15aRZdkPWJ53uZPjmHjRdmHpN2oJWZvsH 0003.pgm
# Processing file 1BlHab_Mqdjiw0E95Vl_iTiP0CeEqHK3B 0004.pgm
# Processing file 1boXEqrcDz4MpftEPOA9Yt-CHDuWJofSk 0005.pgm
# Retrieving folder 1m8eThS3pICpNDiJYxJFybSBKvgivQ-7I mask
# Processing file 14EYP-WfEMszsutu8pM5olV8a36hV641W 0001.png
# Processing file 1IxdAy6RnJSf6g45UxWLU4ib3Wksfpnn2 0002.png
# Processing file 1Zcb4E02Ow4qgGgYjHFF9qW1b5tEbjH4s 0003.png
# Processing file 1p1xeyPSFbMYx6CfsPyIIE0VNDinShk4B 0004.png
# Processing file 1TkJR4IUoT7_RxxRg7jn42lILRux7Vrcd 0005.png
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=18jDfJTkL8ecVHdUkJUAVcsYSMncKowoY
# ...

# %%
Test_single_parameter()
# Out:
# record the image of the step 900...
# record the image of the step 800...
# record the image of the step 700...
# record the image of the step 600...
# record the image of the step 500...
# record the image of the step 400...
# record the image of the step 300...
# record the image of the step 200...
# record the image of the step 100...
# record the image of the step 0...
# Opening image window...
# mse loss: tensor(0.0221, device='cuda:0')
# ssim loss: tensor(0.1021, device='cuda:0')

# %%
Test_set_parameter()
# Out:
# data size: 5
# total test mse: 0.022551624849438668
# total test ssim: 0.09497693777084351
